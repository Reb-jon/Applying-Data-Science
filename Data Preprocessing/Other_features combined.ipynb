# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/Lydia Monoi/Downloads/final_train_data_without_standardization.csv")

# %%
df_test=pd.read_csv("C:/Users/Lydia Monoi/Downloads/final_test_data_without_standardization.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174279 entries, 0 to 174278
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   id                        174279 non-null  int64
#  1   loan_amnt                 174279 non-null  float64
#  2   term                      174279 non-null  int64
#  3   grade                     174279 non-null  int64
#  4   home_ownership            174279 non-null  int64
#  5   pymnt_plan                174279 non-null  int64
#  6   purpose                   174279 non-null  int64
#  7   inq_last_6mths            174279 non-null  float64
#  8   pub_rec                   174279 non-null  float64
#  9   revol_bal                 174279 non-null  float64
#  10  total_acc                 174279 non-null  float64
#  11  initial_list_status       174279 non-null  int64
#  12  recoveries                174279 non-null  float64
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129438 entries, 0 to 129437
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   id                        129438 non-null  int64
#  1   loan_amnt                 129438 non-null  float64
#  2   term                      129438 non-null  int64
#  3   grade                     129438 non-null  int64
#  4   home_ownership            129438 non-null  float64
#  5   pymnt_plan                129438 non-null  int64
#  6   purpose                   129438 non-null  float64
#  7   inq_last_6mths            129438 non-null  float64
#  8   pub_rec                   129438 non-null  float64
#  9   revol_bal                 129438 non-null  float64
#  10  total_acc                 129438 non-null  float64
#  11  initial_list_status       129438 non-null  int64
#  12  recoveries                129438 non-null  float64
# ...

# %%
co2_df=pd.read_csv("C:/Users/Lydia Monoi/Downloads/cleaned_co2_data.csv")

# %%
co2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   State   204 non-null    object
#  1   CO2     204 non-null    float64
#  2   Year    204 non-null    int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 4.9+ KB

# %%
co2_df.head(10)
# Out:
#   State      CO2  Year
# 0    AK  1087.20  2012
# 1    AK   875.02  2014
# 2    AK   925.90  2016
# 3    AK   907.50  2018
# 4    AL   997.65  2012
# 5    AL  1053.86  2014
# 6    AL   912.90  2016
# 7    AL   864.00  2018
# 8    AR  1231.29  2012
# 9    AR  1283.79  2014

# %%
df_1= df.merge(co2_df, left_on=['addr_state', 'issue_year'], right_on=['State', 'Year'], how='left')

# Drop redundant columns if needed
#df_1= df_1.drop(columns=['State', 'Year'])
# Out:
#         id  loan_amnt  term  grade  home_ownership  pymnt_plan  purpose  \
# 0  1590374    35000.0    36      1               1           1        1
# 1  2477367     4925.0    36      2               2           1        2
# 2  1690344    31200.0    60      4               1           1        2
# 3  2214910     5400.0    36      3               3           1        2
# 4  1578408    17500.0    60      5               3           1        2
#
#    inq_last_6mths  pub_rec  revol_bal  ...  emp_length  installment  \
# 0             2.0      0.0    56977.0  ...         6.0      1111.37
# 1             0.0      0.0     4011.0  ...         7.0       169.12
# 2             3.0      0.0    26508.0  ...         0.0       861.36
# 3             1.0      0.0    26384.0  ...         0.0       184.80
# 4             0.0      0.0    17791.0  ...         0.0       451.56
#
#    revol_util  hardship_flag  addr_state  issue_year  loan_status  State  \
# ...

# %%
df_1= df_1.drop(columns=['State', 'Year'])
df_1.head()
# Out:
#         id  loan_amnt  term  grade  home_ownership  pymnt_plan  purpose  \
# 0  1590374    35000.0    36      1               1           1        1
# 1  2477367     4925.0    36      2               2           1        2
# 2  1690344    31200.0    60      4               1           1        2
# 3  2214910     5400.0    36      3               3           1        2
# 4  1578408    17500.0    60      5               3           1        2
#
#    inq_last_6mths  pub_rec  revol_bal  ...  fico_range_low  fico_range_high  \
# 0             2.0      0.0    56977.0  ...           800.0            804.0
# 1             0.0      0.0     4011.0  ...           685.0            689.0
# 2             3.0      0.0    26508.0  ...           690.0            694.0
# 3             1.0      0.0    26384.0  ...           680.0            684.0
# 4             0.0      0.0    17791.0  ...           690.0            694.0
#
# ...

# %%
df_1[df_1['issue_year']==2012].head(20)
# Out:
#          id  loan_amnt  term  grade  home_ownership  pymnt_plan  purpose  \
# 0   1590374    35000.0    36      1               1           1        1
# 1   2477367     4925.0    36      2               2           1        2
# 2   1690344    31200.0    60      4               1           1        2
# 3   2214910     5400.0    36      3               3           1        2
# 4   1578408    17500.0    60      5               3           1        2
# 5   1332505    11500.0    36      1               1           1        4
# 6    969644     5000.0    36      1               3           1        2
# 7   1587763     5000.0    36      3               1           1        5
# 8   2382733    28000.0    36      1               1           1        2
# 9   2524610    22750.0    36      1               3           1        6
# 10  2368838     5500.0    36      2               3           1        2
# 11  2285384    15000.0    36      1               3           1        7
# ...

# %%
ed_df=pd.read_csv("C:/Users/Lydia Monoi/Downloads/cleaned_education_data.csv")
ed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 3 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Year                                                         364 non-null    int64
#  1   State                                                        364 non-null    object
#  2   Population 25 years and over with Bachelor degree or higher  364 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 8.7+ KB

# %%
ed_df['Year'].unique()
# Out:
# array([2012, 2013, 2014, 2015, 2016, 2017, 2018], dtype=int64)

# %%
state_abbreviation_map = {
    'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ', 'Arkansas': 'AR', 'California': 'CA',
    'Colorado': 'CO', 'Connecticut': 'CT', 'Delaware': 'DE', 'Florida': 'FL', 'Georgia': 'GA',
    'Hawaii': 'HI', 'Idaho': 'ID', 'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA', 'Kansas': 'KS',
    'Kentucky': 'KY', 'Louisiana': 'LA', 'Maine': 'ME', 'Maryland': 'MD', 'Massachusetts': 'MA',
    'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS', 'Missouri': 'MO', 'Montana': 'MT',
    'Nebraska': 'NE', 'Nevada': 'NV', 'New Hampshire': 'NH', 'New Jersey': 'NJ', 'New Mexico': 'NM',
    'New York': 'NY', 'North Carolina': 'NC', 'North Dakota': 'ND', 'Ohio': 'OH', 'Oklahoma': 'OK',
    'Oregon': 'OR', 'Pennsylvania': 'PA', 'Rhode Island': 'RI', 'South Carolina': 'SC',
    'South Dakota': 'SD', 'Tennessee': 'TN', 'Texas': 'TX', 'Utah': 'UT', 'Vermont': 'VT',
    'Virginia': 'VA', 'Washington': 'WA', 'West Virginia': 'WV', 'Wisconsin': 'WI', 'Wyoming': 'WY','Puerto Rico': 'PR', 
    'District of Columbia': 'DC'
}

# %%
ed_df['State'] = ed_df['State'].map(state_abbreviation_map)

# %%
missing_states = ed_df[ed_df['State'].isna()]
print(missing_states)  # This will show rows where mapping failed
# Out:
# Empty DataFrame
# Columns: [Year, State, Population 25 years and over with Bachelor degree or higher]
# Index: []

# %%
df_2= df_1.merge(ed_df, left_on=['addr_state', 'issue_year'], right_on=['State', 'Year'], how='left')

# %%
df_test2=df_test.merge(ed_df, left_on=['addr_state', 'issue_year'], right_on=['State', 'Year'], how='left')

# %%
df_2['State'].isna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 174274    False
# 174275    False
# 174276    False
# 174277    False
# 174278    False
# Name: State, Length: 174279, dtype: bool

# %%
df_test2.head()
# Out:
#          id  loan_amnt  term  grade  home_ownership  pymnt_plan  purpose  \
# 0  71746587    19775.0    36      3             3.0           1      8.0
# 1  73954890    10000.0    36      3             1.0           1      2.0
# 2  74635141    30000.0    36      2             1.0           1      2.0
# 3  94333859     6000.0    36      1             3.0           1      2.0
# 4  88770949    21000.0    36      3             3.0           1      8.0
#
#    inq_last_6mths  pub_rec  revol_bal  ...  emp_length  installment  \
# 0             0.0      0.0    20256.0  ...         2.0       635.77
# 1             1.0      0.0     5204.0  ...        10.0       326.21
# 2             0.0      2.0     1721.0  ...        10.0       996.29
# 3             0.0      0.0     2544.0  ...         9.0       188.00
# 4             0.0      0.0    12711.0  ...         4.0       667.70
#
#    revol_util  hardship_flag  addr_state  issue_year  loan_status  Year  \
# ...

# %%
df_test2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129438 entries, 0 to 129437
# Data columns (total 34 columns):
#  #   Column                                                       Non-Null Count   Dtype
# ---  ------                                                       --------------   -----
#  0   id                                                           129438 non-null  int64
#  1   loan_amnt                                                    129438 non-null  float64
#  2   term                                                         129438 non-null  int64
#  3   grade                                                        129438 non-null  int64
#  4   home_ownership                                               129438 non-null  float64
#  5   pymnt_plan                                                   129438 non-null  int64
#  6   purpose                                                      129438 non-null  float64
# ...

# %%
df_2= df_2.drop(columns=['State', 'Year'])
df_2.head()
# Out:
#         id  loan_amnt  term  grade  home_ownership  pymnt_plan  purpose  \
# 0  1590374    35000.0    36      1               1           1        1
# 1  2477367     4925.0    36      2               2           1        2
# 2  1690344    31200.0    60      4               1           1        2
# 3  2214910     5400.0    36      3               3           1        2
# 4  1578408    17500.0    60      5               3           1        2
#
#    inq_last_6mths  pub_rec  revol_bal  ...  fico_range_high  emp_length  \
# 0             2.0      0.0    56977.0  ...            804.0         6.0
# 1             0.0      0.0     4011.0  ...            689.0         7.0
# 2             3.0      0.0    26508.0  ...            694.0         0.0
# 3             1.0      0.0    26384.0  ...            684.0         0.0
# 4             0.0      0.0    17791.0  ...            694.0         0.0
#
#    installment  revol_util  hardship_flag  addr_state  issue_year  \
# ...

# %%
df_test2=df_test2.drop(columns=['State','Year'])
df_test2
# Out:
#                id  loan_amnt  term  grade  home_ownership  pymnt_plan  \
# 0        71746587    19775.0    36      3             3.0           1
# 1        73954890    10000.0    36      3             1.0           1
# 2        74635141    30000.0    36      2             1.0           1
# 3        94333859     6000.0    36      1             3.0           1
# 4        88770949    21000.0    36      3             3.0           1
# ...           ...        ...   ...    ...             ...         ...
# 129433  134286857     8000.0    36      2             1.0           1
# 129434  142068483     7000.0    36      3             2.0           1
# 129435  137231003     2400.0    36      2             1.0           1
# 129436  134479525    10000.0    36      2             1.0           1
# 129437  133492972     6000.0    36      2             3.0           1
#
#         purpose  inq_last_6mths  pub_rec  revol_bal  ...  fico_range_low  \
# ...

# %%
health_df=pd.read_csv("C:/Users/Lydia Monoi/Downloads/cleaned_health_data.csv")
health_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               364 non-null    int64
#  1   State              364 non-null    object
#  2   Percent Uninsured  364 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 8.7+ KB

# %%
health_df.head()
# Out:
#    Year    State  Percent Uninsured
# 0  2012  Alabama               13.3
# 1  2013  Alabama               13.6
# 2  2014  Alabama               12.1
# 3  2015  Alabama               10.1
# 4  2016  Alabama                9.1

# %%
health_df['State'] = health_df['State'].map(state_abbreviation_map)

# %%
df_3= df_2.merge(health_df, left_on=['addr_state', 'issue_year'], right_on=['State', 'Year'], how='left')

# %%
df_test3=df_test2.merge(health_df, left_on=['addr_state', 'issue_year'], right_on=['State', 'Year'], how='left')

# %%
df_3.head(-70)
# Out:
#               id  loan_amnt  term  grade  home_ownership  pymnt_plan  purpose  \
# 0        1590374    35000.0    36      1               1           1        1
# 1        2477367     4925.0    36      2               2           1        2
# 2        1690344    31200.0    60      4               1           1        2
# 3        2214910     5400.0    36      3               3           1        2
# 4        1578408    17500.0    60      5               3           1        2
# ...          ...        ...   ...    ...             ...         ...      ...
# 174204  46837301    14400.0    36      1               3           1        8
# 174205  52758384    12000.0    36      3               1           1        2
# 174206  44573604    12000.0    36      1               2           1        2
# 174207  48050238    20000.0    60      2               1           1        2
# 174208  61912202     3500.0    36      3               2           1        8
#
# ...

# %%
df_test3.head()
# Out:
#          id  loan_amnt  term  grade  home_ownership  pymnt_plan  purpose  \
# 0  71746587    19775.0    36      3             3.0           1      8.0
# 1  73954890    10000.0    36      3             1.0           1      2.0
# 2  74635141    30000.0    36      2             1.0           1      2.0
# 3  94333859     6000.0    36      1             3.0           1      2.0
# 4  88770949    21000.0    36      3             3.0           1      8.0
#
#    inq_last_6mths  pub_rec  revol_bal  ...  installment  revol_util  \
# 0             0.0      0.0    20256.0  ...       635.77        66.9
# 1             1.0      0.0     5204.0  ...       326.21        36.4
# 2             0.0      2.0     1721.0  ...       996.29        25.3
# 3             0.0      0.0     2544.0  ...       188.00        68.8
# 4             0.0      0.0    12711.0  ...       667.70        51.5
#
#    hardship_flag  addr_state  issue_year  loan_status  \
# 0              1          CO        2016            0
# ...

# %%
df_test3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129438 entries, 0 to 129437
# Data columns (total 35 columns):
#  #   Column                                                       Non-Null Count   Dtype
# ---  ------                                                       --------------   -----
#  0   id                                                           129438 non-null  int64
#  1   loan_amnt                                                    129438 non-null  float64
#  2   term                                                         129438 non-null  int64
#  3   grade                                                        129438 non-null  int64
#  4   home_ownership                                               129438 non-null  float64
#  5   pymnt_plan                                                   129438 non-null  int64
#  6   purpose                                                      129438 non-null  float64
# ...

# %%
df_3= df_3.drop(columns=['State', 'Year'])

# %%
df_test3=df_test3.drop(columns=['State', 'Year'])

# %%
pov_df=pd.read_csv("C:/Users/Lydia Monoi/Downloads/cleaned_poverty_data.csv")
pov_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          364 non-null    int64
#  1   State         364 non-null    object
#  2   Poverty Rate  364 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 8.7+ KB

# %%
pov_df.head()
# Out:
#    Year    State  Poverty Rate
# 0  2012  Alabama          19.0
# 1  2013  Alabama          18.7
# 2  2014  Alabama          19.3
# 3  2015  Alabama          18.5
# 4  2016  Alabama          17.1

# %%
pov_df['State'] = pov_df['State'].map(state_abbreviation_map)

# %%
df_4= df_3.merge(pov_df, left_on=['addr_state', 'issue_year'], right_on=['State', 'Year'], how='left')

# %%
df_test4=df_test3.merge(pov_df, left_on=['addr_state', 'issue_year'], right_on=['State', 'Year'], how='left')
df_test4.head()
# Out:
#          id  loan_amnt  term  grade  home_ownership  pymnt_plan  purpose  \
# 0  71746587    19775.0    36      3             3.0           1      8.0
# 1  73954890    10000.0    36      3             1.0           1      2.0
# 2  74635141    30000.0    36      2             1.0           1      2.0
# 3  94333859     6000.0    36      1             3.0           1      2.0
# 4  88770949    21000.0    36      3             3.0           1      8.0
#
#    inq_last_6mths  pub_rec  revol_bal  ...  revol_util  hardship_flag  \
# 0             0.0      0.0    20256.0  ...        66.9              1
# 1             1.0      0.0     5204.0  ...        36.4              1
# 2             0.0      2.0     1721.0  ...        25.3              1
# 3             0.0      0.0     2544.0  ...        68.8              1
# 4             0.0      0.0    12711.0  ...        51.5              1
#
#    addr_state  issue_year  loan_status  \
# 0          CO        2016            0
# ...

# %%
df_4['Poverty Rate'].isna().sum()
# Out:
# 0

# %%
df_4= df_4.drop(columns=['State', 'Year'])

# %%
df_test4=df_test4.drop(columns=['State', 'Year'])

# %%
df_4
# Out:
#               id  loan_amnt  term  grade  home_ownership  pymnt_plan  purpose  \
# 0        1590374    35000.0    36      1               1           1        1
# 1        2477367     4925.0    36      2               2           1        2
# 2        1690344    31200.0    60      4               1           1        2
# 3        2214910     5400.0    36      3               3           1        2
# 4        1578408    17500.0    60      5               3           1        2
# ...          ...        ...   ...    ...             ...         ...      ...
# 174274  41760700     5000.0    36      5               3           1        3
# 174275  40715544    16000.0    36      2               1           1        2
# 174276  66590706    12000.0    60      3               3           1        2
# 174277  52280403    24000.0    36      1               1           1        8
# 174278  68514852    21000.0    36      3               1           1        2
#
# ...

# %%
df_test4['issue_year'].unique()
# Out:
# array([2016, 2017, 2018], dtype=int64)

# %%
df_test4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129438 entries, 0 to 129437
# Data columns (total 34 columns):
#  #   Column                                                       Non-Null Count   Dtype
# ---  ------                                                       --------------   -----
#  0   id                                                           129438 non-null  int64
#  1   loan_amnt                                                    129438 non-null  float64
#  2   term                                                         129438 non-null  int64
#  3   grade                                                        129438 non-null  int64
#  4   home_ownership                                               129438 non-null  float64
#  5   pymnt_plan                                                   129438 non-null  int64
#  6   purpose                                                      129438 non-null  float64
# ...

# %%
df_4=df_4.drop(columns='CO2')
df_4
# Out:
#               id  loan_amnt  term  grade  home_ownership  pymnt_plan  purpose  \
# 0        1590374    35000.0    36      1               1           1        1
# 1        2477367     4925.0    36      2               2           1        2
# 2        1690344    31200.0    60      4               1           1        2
# 3        2214910     5400.0    36      3               3           1        2
# 4        1578408    17500.0    60      5               3           1        2
# ...          ...        ...   ...    ...             ...         ...      ...
# 174274  41760700     5000.0    36      5               3           1        3
# 174275  40715544    16000.0    36      2               1           1        2
# 174276  66590706    12000.0    60      3               3           1        2
# 174277  52280403    24000.0    36      1               1           1        8
# 174278  68514852    21000.0    36      3               1           1        2
#
# ...

# %%
df_4.to_csv('Final_v1.csv', index=False)

# %%
df_test4.to_csv('Final_test_v1.csv',index=False)
